# %%
import os
import pandas as pd
import plotly.express as px

PROJ = '/home/jake/Documents/research/hud/'
os.chdir(PROJ)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
raw_df = pd.read_csv('data/0_raw/hud_2021_raw.csv')
county_df = raw_df.copy()
county_df['fips'] = county_df['fips2010'].apply(lambda x: str(x).split('9999')[0])
county_df.sort_values('fips')


state_df = raw_df.groupby(['state_alpha'])['rent50_1','pop2017'].agg('mean').sort_values('rent50_1',ascending=False)
# Out:
#       Unnamed: 0    fips2010  rent50_0  rent50_1  rent50_2  rent50_3  \
# 2000        2000   109999999       479       556       634       789
# 218          218   100999999       891       950      1093      1421
# 692          692  1000199999       932       964      1131      1619
# 1305        1305  1000399999       970      1121      1358      1689
# 1592        1592  1000599999       703       803      1058      1432
# ...          ...         ...       ...       ...       ...       ...
# 1951        1951   901567400       868       870      1102      1391
# 1952        1952   901573420       868       870      1102      1391
# 1953        1953   901575870       868       870      1102      1391
# 1954        1954   901586790       868       870      1102      1391
# 1955        1955   901588190       868       870      1102      1391
#
#       rent50_4  state         cbsasub21  \
# 2000       925      1  NCNTY01099N01099
# 218       1537      1  METRO13820M13820
# ...

# %%
raw_df
# Out:
#       Unnamed: 0    fips2010  rent50_0  rent50_1  rent50_2  rent50_3  \
# 0              0  4805999999       761       789      1028      1383
# 1              1  4825399999       761       789      1028      1383
# 2              2  4844199999       761       789      1028      1383
# 3              3  7200399999       401       414       472       602
# 4              4  7200599999       401       414       472       602
# ...          ...         ...       ...       ...       ...       ...
# 4761        4761  7213399999       386       395       450       599
# 4762        4762  7214799999       386       395       450       599
# 4763        4763  7801099999       926       945      1154      1435
# 4764        4764  7802099999      1230      1458      1812      2254
# 4765        4765  7803099999       866      1044      1307      1626
#
#       rent50_4  state         cbsasub21  \
# 0         1764     48  METRO10180M10180
# 1         1764     48  METRO10180M10180
# ...
